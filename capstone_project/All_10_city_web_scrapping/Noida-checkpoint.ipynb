# %%
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
import requests
from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
#connecting to webdriver and fetching website
driver=webdriver.Chrome()
driver.get("https://www.nobroker.in/")
driver.maximize_window()

# %%
#clicking on Buy button
buy=driver.find_element(By.XPATH,'//*[@id="app"]/div/div/div[1]/div[3]/div[1]')
buy.click()

# %%
driver.get("https://www.nobroker.in/property/sale/noida/multiple?searchParam=&radius=2.0&city=noida&locality=Noida%20Golf%20Course&isMetro=false")

# %%
#fetching urls
Url_11=[]
for page in range(0,12):
    page_url=driver.find_elements(By.XPATH,'//a[@class="overflow-hidden overflow-ellipsis whitespace-nowrap max-w-80pe po:max-w-full"]')
    for i in page_url:
        Url_11.append(i.get_attribute('href'))

# %%
len(Url_11)
# Out:
# 312

# %%
Url_11
# Out:
# ['https://www.nobroker.in/property/buy/4-bhk-apartment-for-sale-in-noida-sector-137-metro-station-noida/8a9f82038faa4631018faa7af44518d2/detail',
#  'https://www.nobroker.in/property/buy/3-bhk-apartment-for-sale-in-sector-137-noida/8a9f1a8286e038650186e0417db202c3/detail',
#  'https://www.nobroker.in/property/buy/2-bhk-apartment-for-sale-in-sector-137-noida/8a9f82297632637d017632eede4f4b92/detail',
#  'https://www.nobroker.in/property/buy/2-bhk-apartment-for-sale-in-sector-137-noida/8a9fb7827953ccd80179546464c51354/detail',
#  'https://www.nobroker.in/property/buy/2-bhk-apartment-for-sale-in-sector-137-noida/8a9f926074be73d50174be7ffe7c0319/detail',
#  'https://www.nobroker.in/property/buy/3-bhk-apartment-for-sale-in-sector-137-noida/8a9f9222763304a20176330bed2e03d5/detail',
#  'https://www.nobroker.in/property/buy/2-bhk-apartment-for-sale-in-sector-137-noida/8a9f8c838ce2fd27018ce3777b0a76ed/detail',
# ...

# %%
BHK_types=[]
for page in range(0,12):
    try:
        bhk=driver.find_elements(By.XPATH,'//div[@class="font-semibold whitespace-nowrap"]')
        for bhk_element in bhk:
            BHK_types.append(bhk_element.text)
    except NoSuchElementException:
        print("-")

# %%
BHK_types
# Out:
# ['4 BHK',
#  '3 BHK',
#  '2 BHK',
#  '2 BHK',
#  '2 BHK',
#  '3 BHK',
#  '2 BHK',
#  '2 BHK',
#  '3 BHK',
#  '3 BHK',
#  '1 BHK',
#  '4 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '2 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '4 BHK',
#  '3 BHK',
#  '1 RK',
#  '4 BHK',
#  '4 BHK',
#  '3 BHK',
#  '2 BHK',
#  '2 BHK',
#  '2 BHK',
#  '3 BHK',
#  '2 BHK',
#  '2 BHK',
#  '3 BHK',
#  '3 BHK',
#  '1 BHK',
#  '4 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '2 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '4 BHK',
#  '3 BHK',
#  '1 RK',
#  '4 BHK',
#  '4 BHK',
#  '3 BHK',
#  '2 BHK',
#  '2 BHK',
#  '2 BHK',
#  '3 BHK',
#  '2 BHK',
#  '2 BHK',
#  '3 BHK',
#  '3 BHK',
#  '1 BHK',
#  '4 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '2 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '3 BHK',
#  '4 BHK',
#  '3 BHK',
#  '1 RK',
#  '4 BHK',
#  '4 BHK',
#  '3 BHK',
#  '2 BHK',
#  '2 BHK',
#  '2 BHK',
# ...

# %%
len(BHK_types)
# Out:
# 312

# %%
Carpet_area=[]
for page in range(0,12):
    try:
        carpet=driver.find_elements(By.XPATH,'//div[@class="font-semi-bold heading-6"]/div')
        for i in carpet:
            Carpet_area.append(i.text)
    except NoSuchElementException:
        print("-")

# %%
Carpet_area
# Out:
# ['2,645 sqft',
#  '1,900 sqft',
#  '1,240 sqft',
#  '1,000 sqft',
#  '1,045 sqft',
#  '1,360 sqft',
#  '1,045 sqft',
#  '1,110 sqft',
#  '1,560 sqft',
#  '1,315 sqft',
#  '675 sqft',
#  '2,275 sqft',
#  '1,750 sqft',
#  '1,508 sqft',
#  '1,315 sqft',
#  '1,685 sqft',
#  '1,220 sqft',
#  '1,580 sqft',
#  '1,715 sqft',
#  '1,950 sqft',
#  '1,950 sqft',
#  '1,300 sqft',
#  '2,955 sqft',
#  '1,315 sqft',
#  '500 sqft',
#  '2,645 sqft',
#  '2,645 sqft',
#  '1,900 sqft',
#  '1,240 sqft',
#  '1,000 sqft',
#  '1,045 sqft',
#  '1,360 sqft',
#  '1,045 sqft',
#  '1,110 sqft',
#  '1,560 sqft',
#  '1,315 sqft',
#  '675 sqft',
#  '2,275 sqft',
#  '1,750 sqft',
#  '1,508 sqft',
#  '1,315 sqft',
#  '1,685 sqft',
#  '1,220 sqft',
#  '1,580 sqft',
#  '1,715 sqft',
#  '1,950 sqft',
#  '1,950 sqft',
#  '1,300 sqft',
#  '2,955 sqft',
#  '1,315 sqft',
#  '500 sqft',
#  '2,645 sqft',
#  '2,645 sqft',
#  '1,900 sqft',
#  '1,240 sqft',
#  '1,000 sqft',
#  '1,045 sqft',
#  '1,360 sqft',
#  '1,045 sqft',
# ...

# %%
len(Carpet_area)
# Out:
# 312

# %%
#fetching price per square
Price_per_sq=[]
for page in range(0,12):
    
      try:
        price=driver.find_elements(By.XPATH,'//div[@class="nb__7nqQI"]/div[1]/div[2]/div[2]')
           
        for j in price:
               Price_per_sq.append(j.text)
      except NoSuchElementException:
        print("-")

# %%
len(Price_per_sq)
# Out:
# 312

# %%
Price_per_sq
# Out:
# ['₹13,119 per sq.ft.',
#  '₹8,421 per sq.ft.',
#  '₹9,113 per sq.ft.',
#  '₹10,000 per sq.ft.',
#  '₹10,526 per sq.ft.',
#  '₹11,029 per sq.ft.',
#  '₹9,569 per sq.ft.',
#  '₹10,090 per sq.ft.',
#  '₹13,462 per sq.ft.',
#  '₹11,255 per sq.ft.',
#  '₹5,926 per sq.ft.',
#  '₹15,385 per sq.ft.',
#  '₹6,857 per sq.ft.',
#  '₹8,621 per sq.ft.',
#  '₹11,027 per sq.ft.',
#  '₹10,089 per sq.ft.',
#  '₹12,705 per sq.ft.',
#  '₹6,962 per sq.ft.',
#  '₹13,994 per sq.ft.',
#  '₹14,615 per sq.ft.',
#  '₹12,821 per sq.ft.',
#  '₹11,154 per sq.ft.',
#  '₹14,552 per sq.ft.',
#  '₹11,407 per sq.ft.',
#  '₹10,800 per sq.ft.',
#  '₹13,119 per sq.ft.',
#  '₹13,119 per sq.ft.',
#  '₹8,421 per sq.ft.',
#  '₹9,113 per sq.ft.',
#  '₹10,000 per sq.ft.',
#  '₹10,526 per sq.ft.',
#  '₹11,029 per sq.ft.',
#  '₹9,569 per sq.ft.',
#  '₹10,090 per sq.ft.',
#  '₹13,462 per sq.ft.',
#  '₹11,255 per sq.ft.',
#  '₹5,926 per sq.ft.',
#  '₹15,385 per sq.ft.',
#  '₹6,857 per sq.ft.',
#  '₹8,621 per sq.ft.',
# ...

# %%
Car_parking = []

for page in range(0, 312):
    
    try:
        # Fetch car parking element
        car_park = driver.find_element(By.XPATH, '//div[@class="border-3 border-double border-property-views-border-color flex flex-col"]/div[2]/div[2]/div[2]/div[1]')

            
        # Normalize text and check for parking availability
        car_park_text = car_park.text.strip().lower()
        category = 'yes' if 'bike and car' in car_park_text or 'car' in car_park_text else 'no'
        
        # Append category to Car_parking list
        Car_parking.append(category)
        
    except NoSuchElementException:
        Car_parking.append('No')  # Append 'No' if element not found or handle as needed

Car_parking
# Out:
# ['yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
# ...

# %%
len(Car_parking)
# Out:
# 312

# %%
# Initialize lists to store data
Beds = []
Bathroom = []
Balcony = []
Address = []
City=[]
State_code=[]
Country=[]
Landmarks=[]
Furnished_status=[]
Facing=[]
Type_of_ownership=[]
booking_amt=[]
buy_total_price=[]
Status=[]
Floor=[]
Transaction_Type=[]
year_built=[]


# Iterate through each URL to fetch data
for url in Url_11:
    driver.get(url)
    
    ## Fetch bed data
    try:
        bed = driver.find_element(By.XPATH, '//*[@id="details-summary-typeDesc"]')
        Beds.append(bed.text)
    except NoSuchElementException:
        Beds.append('-')

    ## Fetch bathroom data
    try:
        bathroom = driver.find_element(By.XPATH, '//h4[@id="details-summary-bathroom"]')
        Bathroom.append(bathroom.text)
    except NoSuchElementException:
        Bathroom.append('-')

    ## Fetch Balcony data
    try:
        balcony = driver.find_element(By.XPATH, '//div[@class="nb__3Z_gh"][5]/div[2]/span')
        Balcony.append(balcony.text)
    except NoSuchElementException:
        Balcony.append('-')

    ## Fetch address of the house
    try:
        add = driver.find_element(By.XPATH, '//h5[@class="text-muted nb__16pur"]')
        Address.append(add.text)
    except NoSuchElementException:
        Address.append('-')

    ##fetching city
    try:
        City.append('Noida')

    except NouSuchElementException:
        City.append('-')

   
    ##fetching state code
    try:
        State_code.append('120')
    except NouSuchElementException:
        State_code.append('-')

    
     ##fetching country
    try:
        Country.append('India')

    except NouSuchElementException:
        Country.append('-')


     ##fetching Landmarks
    try:
        land=driver.find_element(By.XPATH,'//div[@class="cursor-pointer nb__1Fvam"]/p')
        Landmarks.append(land.text)
    except NoSuchElementException:
        Landmarks.append('-')


    ##fetching Furnished status
    try:
        Furnished=driver.find_element(By.XPATH,'//div[@class="nb__3ocPe"][6]/div[3]')
        Furnished_status.append(Furnished.text)
    except NoSuchElementException:
        Furnished_status.append('-')


    ##fetching facing
    try:
        face=driver.find_element(By.XPATH,'//*[@id="property-detail-body"]/div/div[1]/div/div/section[2]/div/div[1]/div[1]/div/div[2]/div[7]/div[3]/h5')
        Facing.append(face.text)
    except NoSuchElementException:
        Facing.append('-')

    

   ##fetching Type of ownership
    try:
        ownership=driver.find_element(By.XPATH,'//div[@class="nb__28cwR"]/div[2]/div[3]')
        Type_of_ownership.append(ownership.text)
    except NoSuchElementException:
        Type_of_ownership.append('-')


    #fetching booking amount
    #try:
        #book_amt=driver.find_element(By.XPATH,'')
        #booking_amt.append(book_amt.text)
    #except NoSuchElementException:
        #booking_amt.append('-')


    ##fetching buy total price
    try:
        buy_price=driver.find_element(By.XPATH,'//div[@id="formattedPrice"]')
        buy_total_price.append(buy_price.text)
    except NoSuchElementException:
        buy_total_price.append('-')


         
    ##fetching status
    try:
        
        Status.append('complete')
    except NoSuchElementException:
        Status.append('-')


    ##fetching Floor
    try:
        floor=driver.find_element(By.XPATH,'//*[@id="property-detail-body"]/div/div[1]/div/div/section[2]/div/div[1]/div[1]/div/div[2]/div[8]/div[3]/h5')
        Floor .append(floor.text)
    except NoSuchElementException:
        Floor.append('-')

   
    ##fetching Transaction type#  
    try:
        Transition=driver.find_element(By.XPATH,'//div[@class="nb__3Cqpf"]')
        Transaction_Type .append(Transition.text)
    except NoSuchElementException:
        Transaction_Type.append('-')
    Transaction_Type

   
    
    ##fetching year built
    try:
         year=driver.find_element(By.XPATH,'//*[@id="property-detail-body"]/div/div[1]/div/div/section[2]/div/div[1]/div[1]/div/div[2]/div[1]/div[3]/h5')
         year_built .append(year.text)
    except NoSuchElementException:

    ##year_built
        year_built.append('-')

# %%
property_types = []
for url in Url_11:
    try:
        driver.get(url)
        property_type_element = driver.find_element(By.XPATH, '//div[@class="nb__3Z_gh"][6]/div[2]/h5[1]')
        property_type = property_type_element.text.strip().lower()
        category = 'condo' if 'apartment' in property_type else 'house'
        property_types.append(category)

    except NoSuchElementException:
        property_types.append('-')

# %%
print(len(BHK_types),
      len(property_types),
      len(Beds),
      len(Bathroom),
      len(Balcony),
      len(Address),
      len(City),
      len(State_code),
      len(Country),
      len(Landmarks),

      len(Carpet_area),
      len(Status),
      len(Floor),
      len(Transaction_Type),
      len(year_built),
      len(Price_per_sq),
      
      len(Furnished_status),
      len(Facing),
      len(Car_parking),
      len(Type_of_ownership),
      #len(booking_amt),
      len(buy_total_price))
# Out:
# 312 312 312 312 312 312 312 312 312 312 312 312 312 312 312 312 312 312 312 312 312

# %%
# Create DataFrame
data_bang = {'BHK_types':BHK_types,
        'Property_types':property_types,
        'no_of_Beds': Beds,
        'no_of_Bathrooms': Bathroom,
        'no_of_Balcony': Balcony,
        'Address': Address,
        'City': City,
        'State_code': State_code,
        'Country':Country,
        'Landmarks': Landmarks,

        'Carpet_area':Carpet_area,
        'Status':Status,
        'Floor':Floor,
        'Transaction_Type':Transaction_Type,
        'year_built':year_built,
        'price_per_square_feet':Price_per_sq,
        
             
        'Furnished_status':Furnished_status,
        'Facing':Facing,
        'Car_parking':Car_parking,
        'Type_of_ownership':Type_of_ownership,
        #'booking_amt':booking_amt,
        'buy_total_price':buy_total_price,


             
}
df_Noida = pd.DataFrame(data_bang)

# %%
df_Noida
# Out:
#     BHK_types Property_types no_of_Beds no_of_Bathrooms no_of_Balcony  \
# 0       4 BHK          condo  4 Bedroom      4 Bathroom             5
# 1       3 BHK          condo  3 Bedroom      3 Bathroom             4
# 2       2 BHK          condo  2 Bedroom      2 Bathroom             3
# 3       2 BHK          condo  2 Bedroom      2 Bathroom            NA
# 4       2 BHK          condo  2 Bedroom      2 Bathroom            NA
# ..        ...            ...        ...             ...           ...
# 307     3 BHK          condo  3 Bedroom      2 Bathroom             2
# 308     4 BHK          condo  4 Bedroom      4 Bathroom             3
# 309     3 BHK          condo  3 Bedroom      2 Bathroom            NA
# 310      1 RK          condo  1 Bedroom      1 Bathroom             1
# 311     4 BHK          condo  4 Bedroom      4 Bathroom             5
#
#                                                Address   City State_code  \
# ...

# %%
csv_filename = 'df_Noida.csv'
df_Noida.to_csv(csv_filename, index=False)

print(f"DataFrame successfully converted and saved to {csv_filename}")
# Out:
# DataFrame successfully converted and saved to df_Noida.csv

# %%
driver.close()
